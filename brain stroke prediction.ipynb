# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("healthcare-dataset-stroke-data.csv")
# Make a copy of the dataset
bsp_df = df.copy()
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.shape
# Out:
# (5110, 12)

# %%
df.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %% [markdown]
# #### To check if there any null values present in datset

# %%
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
#count the missing values in bmi column.
df.bmi.isnull().sum()
# Out:
# 201

# %%
#calculate the percentage of missing values in bmi column.
float(100.0*201/45211)
# Out:
# 0.4445820707349981

# %%
#drop the records with bmi missing in df and copy in df1 dataframe.
df1= df[-df.bmi.isnull()].copy()
df1.shape
# Out:
# (4909, 12)

# %%
#count the missing values in bmi column.
df1.bmi.isnull().sum()
# Out:
# 0

# %%
df1.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df1.bmi.describe()
# Out:
# count    4909.000000
# mean       28.893237
# std         7.854067
# min        10.300000
# 25%        23.500000
# 50%        28.100000
# 75%        33.100000
# max        97.600000
# Name: bmi, dtype: float64

# %%
# Dimensions of DataFrame
df1.ndim
# Out:
# 2

# %%
# To find Central location of data from b
df1.mean()
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_11824/1278323070.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.mean()
# id                   37064.313506
# age                     42.865374
# hypertension             0.091872
# heart_disease            0.049501
# avg_glucose_level      105.305150
# bmi                     28.893237
# stroke                   0.042575
# dtype: float64

# %%
df1.median()
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_11824/2279417019.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.median()
# id                   37608.00
# age                     44.00
# hypertension             0.00
# heart_disease            0.00
# avg_glucose_level       91.68
# bmi                     28.10
# stroke                   0.00
# dtype: float64

# %%
# Standard deviation
df1.std()
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_11824/1813207459.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.std()
# id                   20995.098457
# age                     22.555115
# hypertension             0.288875
# heart_disease            0.216934
# avg_glucose_level       44.424341
# bmi                      7.854067
# stroke                   0.201917
# dtype: float64

# %%
# Variance
df1.var()
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_11824/2871271835.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.var()
# id                   4.407942e+08
# age                  5.087332e+02
# hypertension         8.344859e-02
# heart_disease        4.706016e-02
# avg_glucose_level    1.973522e+03
# bmi                  6.168636e+01
# stroke               4.077055e-02
# dtype: float64

# %%
# Correlation
corr = df1.corr()
corr
# Out:
#                          id       age  hypertension  heart_disease  \
# id                 1.000000  0.008984      0.001147       0.004016
# age                0.008984  1.000000      0.274425       0.257123
# hypertension       0.001147  0.274425      1.000000       0.115991
# heart_disease      0.004016  0.257123      0.115991       1.000000
# avg_glucose_level  0.006409  0.235838      0.180543       0.154525
# bmi                0.003084  0.333398      0.167811       0.041357
# stroke             0.004839  0.232331      0.142515       0.137938
#
#                    avg_glucose_level       bmi    stroke
# id                          0.006409  0.003084  0.004839
# age                         0.235838  0.333398  0.232331
# hypertension                0.180543  0.167811  0.142515
# heart_disease               0.154525  0.041357  0.137938
# avg_glucose_level           1.000000  0.175502  0.138936
# bmi                         0.175502  1.000000  0.042374
# ...

# %%
# The skew () method calculates the skew for each column
# The skew () method searches column-wise and returns the skew of each row
df1.skew()
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_11824/336109200.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.skew()
# id                  -0.039951
# age                 -0.119070
# hypertension         2.826791
# heart_disease        4.155030
# avg_glucose_level    1.614026
# bmi                  1.055340
# stroke               4.532666
# dtype: float64

# %%
df.age.describe()
# Out:
# count    5110.000000
# mean       43.226614
# std        22.612647
# min         0.080000
# 25%        25.000000
# 50%        45.000000
# 75%        61.000000
# max        82.000000
# Name: age, dtype: float64

# %%
#plot the histogram of age variable.
df.age.plot.hist()
plt.show()

# %%
#plot the boxplot of bmi variable.
sns.boxplot(df1.bmi)
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#pie chart
df1 = df1['bmi'].value_counts()
plt.pie(df1, labels=df1.index, autopct="%.0f%%");

# %%
#plot the pie chart of work_type categories
df.work_type.value_counts(normalize=True).plot.pie()
plt.show()

# %%
#calculate the percentage of each worktype category. 
df.work_type.value_counts(normalize=True)
# Out:
# Private          0.572407
# Self-employed    0.160274
# children         0.134442
# Govt_job         0.128571
# Never_worked     0.004305
# Name: work_type, dtype: float64

# %%
#plot the bar graph of percentage worktype categories
df.work_type.value_counts(normalize=True).plot.barh()
plt.show()

# %%
#calculate the percentage of each ever_married category. 
df.ever_married.value_counts(normalize=True)
# Out:
# Yes    0.656164
# No     0.343836
# Name: ever_married, dtype: float64

# %%
#plot the pie chart of ever_married categories
df.ever_married.value_counts(normalize=True).plot.pie()
plt.show()

# %%
#calculate the percentage of each Residence_type category. 
df.Residence_type.value_counts(normalize=True)
# Out:
# Urban    0.508023
# Rural    0.491977
# Name: Residence_type, dtype: float64

# %%
#plot the pie chart of Residence_type categories
df.Residence_type.value_counts(normalize=True).plot.pie()
plt.show()

# %%
#calculate the percentage of each smoking_status category.
df.smoking_status.value_counts(normalize=True).plot.bar()
plt.show()

# %%
# Calculate the percentage of each work_type category
df.work_type.value_counts(normalize=True)
# Out:
# Private          0.572407
# Self-employed    0.160274
# children         0.134442
# Govt_job         0.128571
# Never_worked     0.004305
# Name: work_type, dtype: float64

# %%
# Plot the bar graph of percentage work_type categories
df.work_type.value_counts(normalize=True).plot.barh()
plt.show()

# %%
df.groupby(["smoking_status"])["age"].mean().plot.bar()
plt.show()

# %%
df.groupby(["smoking_status"])["avg_glucose_level"].mean().plot.bar()
plt.show()

# %%
res=pd.pivot_table(data=df,index="Residence_type",columns="smoking_status",values="bmi")
res
# Out:
# smoking_status    Unknown  formerly smoked  never smoked     smokes
# Residence_type
# Rural           25.571680        31.067322     29.814819  30.989583
# Urban           25.760134        30.444186     30.154705  30.169825

# %%
sns.heatmap(res,annot=True)
# Out:
# <AxesSubplot:xlabel='smoking_status', ylabel='Residence_type'>

# %%
plt.subplots(figsize=(28,8))
corr = df.corr()
sns.heatmap(corr,annot=True,
           xticklabels = corr.columns.values,
           yticklabels = corr.columns.values);
plt.show()

# %%
sns.pairplot(data=df,vars=["Residence_type","smoking_status","bmi"])
plt.show()

# %%
df['age'] =df['age'].astype(int)

# %%
# NUMERICAL - NUMERICAL ASSOCIATIONS
plt.scatter(df.age,df.bmi)
plt.show()

# %%
sns.boxplot(data=df.loc[:, ['bmi', 'age']])
# Out:
# <AxesSubplot:>

# %%
#groupby the response to find the mean of the age with response male,female and others seperatly.
df.groupby("gender")["bmi"].mean()
# Out:
# gender
# Female    29.065758
# Male      28.647936
# Other     22.400000
# Name: bmi, dtype: float64

# %%
#groupby the response to find the median of the age with response male,female and others seperatly.
df.groupby("gender")["bmi"].median()
# Out:
# gender
# Female    27.8
# Male      28.4
# Other     22.4
# Name: bmi, dtype: float64

# %%
#plot the box plot of bmi for male,female and others responses.
sns.boxplot(data=df,x="gender",y="bmi")
# Out:
# <AxesSubplot:xlabel='gender', ylabel='bmi'>

# %%
sns.boxplot(data=df.loc[:, [ "ever_married","age"]])
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df[["age","bmi","avg_glucose_level"]].corr(),annot=True,cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
#plot the pair plot of bmi, balance and age in df dataframe.
sns.pairplot(data=df,vars=["bmi","age","avg_glucose_level"])
plt.show()
